# %%
# Catalina Savage
# AST 5263
# Lab 3 - Leucus Occultation

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits

# %%
# frame_01116.fits
hdul_01116 = fits.open( 'T17_snipped_FITS/frame_01116.fits' )
img_01116  = hdul_01116[ 0 ].data

plt.imshow( img_01116 )
hdul_01116[ 0 ].header
# Out:
# SIMPLE  =                    T / C# FITS: 11/18/2018 02:41:35
# BITPIX  =                   16
# NAXIS   =                    2 / Dimensionality
# NAXIS1  =                 1920
# NAXIS2  =                 1200
# GAIN    =                  300 /
# OBSLONG =            -100.7388 /
# OBSLAT  =     29.4374176666667 /
# GPSSTAT = 'Locked  '           /
# DATE-END= '2018-11-18T02:41:35.3885403' / System Clock:Frame Received
# DATE-OBS= '2018-11-18T02:41:41.2610093' / GPS:Start Exposure
# SWCREATE= 'SharpCap'           / 3.2.5865.0
# CCD-TEMP=                    0 /
# XBINNING=                    1 /
# BLKLEVEL=                  100 /
# YPIXSZ  =      5.8600001335144 /
# XPIXSZ  =      5.8600001335144 /
# EXPTIME =                 0.25 /
# BSCALE  =                    1 /
# BZERO   =                32768 /
# EXTEND  =                    T / Extensions are permitted
# YBINNING=                    1 /
# INSTRUME= 'QHY174M '           /

# %%
# frame_01128.fits
hdul_01128 = fits.open( 'T17_snipped_FITS/frame_01128.fits' )
img_01128  = hdul_01128[ 0 ].data

plt.imshow( img_01128 )
hdul_01128[ 0 ].header
# Out:
# SIMPLE  =                    T / C# FITS: 11/18/2018 02:41:38
# BITPIX  =                   16
# NAXIS   =                    2 / Dimensionality
# NAXIS1  =                 1920
# NAXIS2  =                 1200
# GAIN    =                  300 /
# OBSLONG =            -100.7388 /
# OBSLAT  =     29.4374181666667 /
# GPSSTAT = 'Locked  '           /
# DATE-END= '2018-11-18T02:41:38.3824050' / System Clock:Frame Received
# DATE-OBS= '2018-11-18T02:41:44.2680645' / GPS:Start Exposure
# SWCREATE= 'SharpCap'           / 3.2.5865.0
# CCD-TEMP=                 -0.1 /
# XBINNING=                    1 /
# BLKLEVEL=                  100 /
# YPIXSZ  =      5.8600001335144 /
# XPIXSZ  =      5.8600001335144 /
# EXPTIME =                 0.25 /
# BSCALE  =                    1 /
# BZERO   =                32768 /
# EXTEND  =                    T / Extensions are permitted
# YBINNING=                    1 /
# INSTRUME= 'QHY174M '           /
